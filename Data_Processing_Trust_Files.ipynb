# %%
filepath1 = 'Dataset/epinion_preprocessed.csv'
import pandas as pd
df1 = pd.read_csv(filepath1)
df1['user'] = df1['user'].str.lower()
df1.count()
# Out:
# item      188484
# paid      188296
# review    188484
# stars     188484
# time      188484
# user      188483
# dtype: int64

# %%
df1.head()
# Out:
#                                                 item  paid  \
# 0            pr-Sony_KV_36FS12__Standard_Televisions  1199
# 1                 Minolta_QMS_PagePro_1250E_Printers   260
# 2  Sony_VAIO_PCG_K45_P4_538_3_2GHz_1MB_L2_533MHz_...  1800
# 3  Sony_VAIO_PCG_K45_P4_538_3_2GHz_1MB_L2_533MHz_...  1000
# 4              pr-Durabrand_CD-85_Personal_CD_Player    20
#
#                                               review  stars        time  \
# 0  well when i graduated from college it didnt ta...      5  1012262400
# 1  i got this printer from minolta as a warranty ...      4  1027296000
# 2  although i love my vaio especially the gorgeou...      2  1201305600
# 3  this is my first laptop and i bought it about ...      4  1118016000
# 4  just recently my sony dej001 walkman died on m...      4  1149292800
#
#          user
# 0      pyros7
# 1      fgb59h
# 2    bucho_ky
# 3     redp944
# 4  spongebag7

# %%
df1.drop_duplicates(inplace = True)

# %%
df1.count()
# Out:
# item      188433
# paid      188245
# review    188433
# stars     188433
# time      188433
# user      188432
# dtype: int64

# %%
filepath2 = 'Dataset/network_trust_preprocessed.csv'
df2 = pd.read_csv(filepath2)
df2['user1'] = df2['user1'].str.lower()
df2['user2'] = df2['user2'].str.lower()

# %%
df2.count()
# Out:
# user1    691872
# trust    691892
# user2    691568
# dtype: int64

# %%
df2.drop_duplicates(inplace = True)

# %%
print(df2.count())
print(df2.head())
# Out:
# user1    543381
# trust    543401
# user2    543153
# dtype: int64
#            user1  trust        user2
# 0  lavenderfruit  trust   kristinafh
# 1      shippo225  trust      sallyg8
# 2      aryeh7000  trust      liteair
# 3       chiquita  trust   magenta321
# 4   jeffsullivan  trust  rpllingrock

# %%
result = pd.merge(df1, df2, how='left', left_on='user', right_on='user1')
result1 = pd.merge(df1, df2, how='left', left_on='user', right_on='user2')

# %%
result.head()
# Out:
#                                                 item  paid  \
# 0            pr-Sony_KV_36FS12__Standard_Televisions  1199
# 1                 Minolta_QMS_PagePro_1250E_Printers   260
# 2  Sony_VAIO_PCG_K45_P4_538_3_2GHz_1MB_L2_533MHz_...  1800
# 3  Sony_VAIO_PCG_K45_P4_538_3_2GHz_1MB_L2_533MHz_...  1000
# 4              pr-Durabrand_CD-85_Personal_CD_Player    20
#
#                                               review  stars        time  \
# 0  well when i graduated from college it didnt ta...      5  1012262400
# 1  i got this printer from minolta as a warranty ...      4  1027296000
# 2  although i love my vaio especially the gorgeou...      2  1201305600
# 3  this is my first laptop and i bought it about ...      4  1118016000
# 4  just recently my sony dej001 walkman died on m...      4  1149292800
#
#          user       user1  trust   user2
# 0      pyros7         NaN    NaN     NaN
# 1      fgb59h         NaN    NaN     NaN
# 2    bucho_ky         NaN    NaN     NaN
# ...

# %%
result1.head()
# Out:
#                                                 item  paid  \
# 0            pr-Sony_KV_36FS12__Standard_Televisions  1199
# 1                 Minolta_QMS_PagePro_1250E_Printers   260
# 2  Sony_VAIO_PCG_K45_P4_538_3_2GHz_1MB_L2_533MHz_...  1800
# 3  Sony_VAIO_PCG_K45_P4_538_3_2GHz_1MB_L2_533MHz_...  1000
# 4              pr-Durabrand_CD-85_Personal_CD_Player    20
#
#                                               review  stars        time  \
# 0  well when i graduated from college it didnt ta...      5  1012262400
# 1  i got this printer from minolta as a warranty ...      4  1027296000
# 2  although i love my vaio especially the gorgeou...      2  1201305600
# 3  this is my first laptop and i bought it about ...      4  1118016000
# 4  just recently my sony dej001 walkman died on m...      4  1149292800
#
#          user   user1  trust       user2
# 0      pyros7     NaN    NaN         NaN
# 1      fgb59h     NaN    NaN         NaN
# 2    bucho_ky     NaN    NaN         NaN
# ...

# %%
result = result.append(result1)

# %%
result.head(50)
# Out:
#                                                  item  paid  \
# 0             pr-Sony_KV_36FS12__Standard_Televisions  1199
# 1                  Minolta_QMS_PagePro_1250E_Printers   260
# 2   Sony_VAIO_PCG_K45_P4_538_3_2GHz_1MB_L2_533MHz_...  1800
# 3   Sony_VAIO_PCG_K45_P4_538_3_2GHz_1MB_L2_533MHz_...  1000
# 4               pr-Durabrand_CD-85_Personal_CD_Player    20
# 5               pr-Durabrand_CD-85_Personal_CD_Player    20
# 6               pr-Durabrand_CD-85_Personal_CD_Player    20
# 7               pr-Durabrand_CD-85_Personal_CD_Player    20
# 8               pr-Durabrand_CD-85_Personal_CD_Player    20
# 9               pr-Durabrand_CD-85_Personal_CD_Player    20
# 10              pr-Durabrand_CD-85_Personal_CD_Player    20
# 11              pr-Durabrand_CD-85_Personal_CD_Player    20
# 12              pr-Durabrand_CD-85_Personal_CD_Player    20
# 13              pr-Durabrand_CD-85_Personal_CD_Player    20
# 14              pr-Durabrand_CD-85_Personal_CD_Player    20
# ...

# %%
result.drop_duplicates(inplace = True)

# %%
result.count()
# Out:
# item      3652757
# paid      3645472
# review    3652757
# stars     3652757
# time      3652757
# user      3652489
# user1     3500658
# trust     3500681
# user2     3500201
# dtype: int64

# %%
result['user2'].nunique()
# Out:
# 37256

# %%
result['user1'].nunique()
# Out:
# 33325

# %%
result['user'].nunique()
# Out:
# 116259

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html

result.dropna(subset=['user1', 'trust', 'user2'], inplace = True)

# %%
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
result.count()
# Out:
# item      3500178
# paid      3493012
# review    3500178
# stars     3500178
# time      3500178
# user      3500178
# user1     3500178
# trust     3500178
# user2     3500178
# dtype: int64

# %%
result.head()
# Out:
#                                     item paid  \
# 4  pr-Durabrand_CD-85_Personal_CD_Player   20
# 5  pr-Durabrand_CD-85_Personal_CD_Player   20
# 6  pr-Durabrand_CD-85_Personal_CD_Player   20
# 7  pr-Durabrand_CD-85_Personal_CD_Player   20
# 8  pr-Durabrand_CD-85_Personal_CD_Player   20
#
#                                               review  stars        time  \
# 4  just recently my sony dej001 walkman died on m...      4  1149292800
# 5  just recently my sony dej001 walkman died on m...      4  1149292800
# 6  just recently my sony dej001 walkman died on m...      4  1149292800
# 7  just recently my sony dej001 walkman died on m...      4  1149292800
# 8  just recently my sony dej001 walkman died on m...      4  1149292800
#
#          user       user1  trust       user2
# 4  spongebag7  spongebag7  trust      cyndia
# 5  spongebag7  spongebag7  trust      amyk49
# 6  spongebag7  spongebag7  trust     rated-r
# 7  spongebag7  spongebag7  trust  trailhound
# ...

# %%
result.to_csv('Dataset/epinion_network_trust.csv')

# %%
filepath3 = 'Dataset/network_trustedby_preprocessed.csv'
df3 = pd.read_csv(filepath3)
df3['user1'] = df3['user1'].str.lower()
df3['user2'] = df3['user2'].str.lower()
df3.count()
# Out:
# user1        691875
# trustedby    691895
# user2        691570
# dtype: int64

# %%
df3.drop_duplicates(inplace = True)

# %%
print(df3.count())
print(df3.head())
# Out:
# user1        543383
# trustedby    543403
# user2        543154
# dtype: int64
#            user1  trustedby       user2
# 0  lavenderfruit  trustedby  kristinafh
# 1       rosalyce  trustedby      cindee
# 2        sharkie  trustedby      theeye
# 3       chiquita  trustedby  magenta321
# 4       valerieg  trustedby   jabbrjwz2

# %%
result = pd.merge(df1, df3, how='left', left_on='user', right_on='user1')
result1 = pd.merge(df1, df3, how='left', left_on='user', right_on='user2')

# %%
result = result.append(result1)

# %%
result.head()
# Out:
#                                                 item  paid  \
# 0            pr-Sony_KV_36FS12__Standard_Televisions  1199
# 1                 Minolta_QMS_PagePro_1250E_Printers   260
# 2  Sony_VAIO_PCG_K45_P4_538_3_2GHz_1MB_L2_533MHz_...  1800
# 3  Sony_VAIO_PCG_K45_P4_538_3_2GHz_1MB_L2_533MHz_...  1000
# 4              pr-Durabrand_CD-85_Personal_CD_Player    20
#
#                                               review  stars        time  \
# 0  well when i graduated from college it didnt ta...      5  1012262400
# 1  i got this printer from minolta as a warranty ...      4  1027296000
# 2  although i love my vaio especially the gorgeou...      2  1201305600
# 3  this is my first laptop and i bought it about ...      4  1118016000
# 4  just recently my sony dej001 walkman died on m...      4  1149292800
#
#          user       user1  trustedby       user2
# 0      pyros7         NaN        NaN         NaN
# 1      fgb59h         NaN        NaN         NaN
# ...

# %%
result.drop_duplicates(inplace = True)

# %%
result.dropna(subset=['user1', 'trustedby', 'user2'], inplace = True)

# %%
result.to_csv('Dataset/epinion_network_trustedby.csv')

# %%
result.count()
# Out:
# item         3500183
# paid         3493017
# review       3500183
# stars        3500183
# time         3500183
# user         3500183
# user1        3500183
# trustedby    3500183
# user2        3500183
# dtype: int64

# %%
df_new = result[['user2', 'user1']]

# %%
df_new.count()
# Out:
# user2    3500183
# user1    3500183
# dtype: int64

# %%
df_new.head()
# Out:
#            user2       user1
# 4     rcaarmsc07  spongebag7
# 5     blindsider  spongebag7
# 6        bruguru  spongebag7
# 7  speeddemon531  spongebag7
# 8         cyndia  spongebag7

# %%
df_new.drop_duplicates(inplace = True)
# Out:
# /Users/shalu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new.columns = ['user1', 'user2']

# %%
df_new.count()
# Out:
# user1    359295
# user2    359295
# dtype: int64

# %%
path = 'Dataset/epinion_network_trust.csv'
import pandas as pd
df = pd.read_csv(path)

# %%
df = df[['user1', 'user2']]

# %%
df.drop_duplicates(inplace = True)

# %%
df.count()
# Out:
# user1    359294
# user2    359294
# dtype: int64

# %%
#df_new = df_new.append(df[['user1','user2']])
df_new = pd.concat([df_new, df])

# %%
df_new.count()
# Out:
# user1    718589
# user2    718589
# dtype: int64

# %%
df_new.drop_duplicates(inplace = True)

# %%
df_new.count()
# Out:
# user1    566241
# user2    566241
# dtype: int64

# %%
df_new.to_csv('Dataset/epinion_network_trust_new.csv', index = False)

# %%
df_new[df_new['user1'].str.isalnum() ==False].to_csv('Dataset/check_user_entry.csv', index = False)

# %%
df_new[df_new['user1'].str.isdigit() ==True].head(10)
# Out:
#          user1      user2
# 106     401402    bhweb22
# 634     401402   briancam
# 2925      1360   jpalacio
# 3412    401402  beavis612
# 4274      2463    mszorak
# 4428  10486300    mszorak
# 5388    582974    mszorak
# 5429      3517    mszorak
# 5928      3830        vi9
# 5930    401402        vi9
